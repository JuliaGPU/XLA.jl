# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliaTPU/XLA.jl/blob/master/docs/InstallJuliaXLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download and install julia and the Julia:XLA compiler
#
# In order to proceed, we need to download and install, the custom branch of julia into the container used by the colaboratory backend. Please note the colab containers are ephemeral and you will need to re-run this notebook before any julia TPU-based notebook.

# %%
# !curl -sSL "https://storage.googleapis.com/julia-tpu-binaries/julia.v1.1.0-kf.tpu3.x86_64-linux-gnu.tar.gz" -o julia.tar.gz
# !tar -xzf julia.tar.gz -C /usr
# !rm -rf julia.tar.gz*
# !julia -e 'using Pkg; pkg"add IJulia;"'
# Download and install the XLA Compiler
# !if [ ! -d XLA.jl ]; then git clone https://github.com/JuliaTPU/XLA.jl; fi
# !cd XLA.jl && git pull
# !cd XLA.jl && julia --project=. -e 'using Pkg; pkg"instantiate"'
# Out:
#    Cloning default registries into /root/.julia/registries
#    Cloning registry General from "https://github.com/JuliaRegistries/General.git"
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#  Installed Conda ─────────── v1.1.1
#  Installed VersionParsing ── v1.1.3
#  Installed SoftGlobalScope ─ v1.0.7
#  Installed JSON ──────────── v0.19.0
#  Installed ZMQ ───────────── v1.0.0
#  Installed BinaryProvider ── v0.5.2
#  Installed IJulia ────────── v1.13.0
#  Installed MbedTLS ───────── v0.6.5
#  Installed Compat ────────── v1.3.0
#   Updating `~/.julia/environments/v1.1/Project.toml`
#   [7073ff75] + IJulia v1.13.0
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#   [b99e7846] + BinaryProvider v0.5.2
#   [34da2185] + Compat v1.3.0
#   [8f4d0f93] + Conda v1.1.1
#   [7073ff75] + IJulia v1.13.0
#   [682c06a0] + JSON v0.19.0
#   [739be429] + MbedTLS v0.6.5
# ...

# %% [markdown]
# ## Open a TPU based notebook
#
# Upon completion of the above cell, julia support will be available in this container. However, the notebook kernel gets decided at open time and thus you will need to open a new notebook that is set to use the julia kernel. Be sure not to reset the runtime as that will undo this installation; uncheck the reset box upon opening each new notebook. We recommend getting started with these examples. Please note that only notebook 3 is currently designed to be run on Colab:
#
# 1. [ResNet50 on TPUs](https://colab.research.google.com/github/JuliaTPU/XLA.jl/blob/master/examples/1_ResNet_Intro.ipynb)
# 2. [Training with ResNet50](https://colab.research.google.com/github/JuliaTPU/XLA.jl/blob/master/examples/2_ResNet_Training.ipynb)
# 3. [Distributed training of an LSTM](https://colab.research.google.com/github/JuliaTPU/XLA.jl/blob/master/examples/3_LSTM_DistributedTraining.ipynb)
